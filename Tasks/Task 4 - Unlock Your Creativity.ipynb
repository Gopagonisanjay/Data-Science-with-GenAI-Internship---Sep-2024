# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont ,ImageColor
img =  Image.open(r"C:\Users\sanja\Downloads\meme1.jpg")
text_1 = """When I was 
creating memes"""

font_1 = ImageFont.truetype(r"C:\Users\sanja\Downloads\Roboto\Roboto-MediumItalic.ttf",50)


draw = ImageDraw.Draw(img)

draw.text((650,100),text_1,fill="red",font = font_1)

plt.imshow(img)

# %%
font_2 = ImageFont.truetype(r"C:\Users\sanja\Downloads\Roboto\Roboto-MediumItalic.ttf",60)
text_2 = """** le 
my dad reaction"""
draw.text((600,500),text_2,fill = "red",font = font_2,align='left')
plt.imshow(img)

# %%
font_3 = ImageFont.truetype(r"C:\Users\sanja\Downloads\Roboto\Roboto-MediumItalic.ttf",50)
text_3 = """** lee my frd
you were born to make memes"""
draw.text((300,980),text_3,fill = "red",font = font_3)
plt.imshow(img)
